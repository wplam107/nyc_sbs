# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pickle

# %%
with open('nyc_data.p', 'rb') as f:
    df = pickle.load(f)

# %%
df
# Out:
#                                                 geometry       median  \
# zip
# 10065  POLYGON ((-73.97210 40.76552, -73.97165 40.766...  108154.9505
# 10075  POLYGON ((-73.96469 40.77568, -73.96423 40.776...  112267.5519
# 10128  MULTIPOLYGON (((-73.93951 40.77922, -73.93957 ...  105186.9788
# 10280  POLYGON ((-74.01960 40.70564, -74.01955 40.706...   98937.8355
# 10301  MULTIPOLYGON (((-74.09460 40.61219, -74.09442 ...   56776.4674
# ...                                                  ...          ...
# 11432  POLYGON ((-73.81184 40.71787, -73.81177 40.717...   50291.2065
# 11433  POLYGON ((-73.80396 40.70105, -73.80348 40.701...   41780.0631
# 11434  POLYGON ((-73.80216 40.66525, -73.80183 40.665...   51640.5104
# 11435  POLYGON ((-73.82569 40.71607, -73.82557 40.716...   44721.7965
# 11436  POLYGON ((-73.80570 40.68295, -73.80519 40.683...   62297.1561
#
#               mean    pop  eligible
# zip
# 10065  191673.5228  31500         0
# 10075  188422.4971  25187         0
# ...
